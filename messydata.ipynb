# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style='whitegrid')

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("yagunnersya/fifa-21-messy-raw-dataset-for-cleaning-exploring")

print("Path to dataset files:", path)
# Out:
# Downloading to C:\Users\TAJ\.cache\kagglehub\datasets\yagunnersya\fifa-21-messy-raw-dataset-for-cleaning-exploring\2.archive...
# 100%|███████████████████████████████████████████████████████████████| 5.28M/5.28M [00:00<00:00, 8.48MB/s]
# Extracting files...
# Path to dataset files: C:\Users\TAJ\.cache\kagglehub\datasets\yagunnersya\fifa-21-messy-raw-dataset-for-cleaning-exploring\versions\2

# %%
import os

# %%
print(os.listdir(path))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(os.listdir(path))
#
# NameError: name 'os' is not defined
